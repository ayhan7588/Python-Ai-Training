# %% [markdown]
# <a href="https://colab.research.google.com/github/ayhan7588/Python-Ai-Training/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=[2,4,6,15,24]
y=[4,5,9,20,27]
plt.plot(x,y)
plt.xlabel('x-ekseni')
plt.ylabel('y-ekseni')
plt.title('çizgi',loc='right',color='red')
plt.legend(['Çizgi'])
plt.grid(True)

plt.show()

# %%
x_aksis=[2,4,7,15,24,56,60]
y_aksis=[4,7,8,20,27,25,19]
plt.plot(x_aksis,y_aksis)
pl

# %%
meyveler=["elma","armut","muz"]
counts=[10,20,30]
plt.bar(meyveler,counts)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# scater(dağılım grfiği)

# %%
x=[2,4,6,15,24]
y=[4,5,9,20,27]
plt.scatter(x,y, color="red")
plt.show()

# %% [markdown]
# grafiklerin özelleştrilmesi

# %%
x=[2,4,6,15,24]
y=[4,5,9,20,27]
plt.xlabel('x-ekseni')
plt.ylabel('y-ekseni')
plt.legend(['Çizgi'])
plt.grid(True)
plt.plot(x,y)
plt.show()

# %%
x=[2,4,6,15,24]
y=[4,5,9,20,27]
plt.figure(figsize=(5,5))
plt.plot(x,y)
plt.show()

# %%
x=[2,4,6,15,24]
y=[4,5,9,20,27]
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(x,y)
x=[2,4,6,15,24]
y=[7,12,13,20,27]
plt.subplot(1,2,2)
plt.tight_layout()
plt.plot(x,y)

# %%
x=[2,4,6,15,24]
y=[4,5,9,20,27]
y1=[7,12,13,20,27]
plt.plot(x,y, label="çay",marker="+")
plt.plot(x,y1,label="kahve",marker="o")
plt.legend()
plt.show()

# %%
x=np.linspace(0,10,100)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)
y4=np.sqrt(x)

plt.plot(x,y1, label='sin(x)')
plt.plot(x,y2, label='cos(x)')
plt.plot(x,y3, label='tan(x)')
plt.plot(x,y4, label='sqrt(x)')

plt.legend()
plt.show()
